# %% [markdown]
# <a href="https://colab.research.google.com/github/juanitasarmiento/Modelado-y-simulacion/blob/main/Tarea_cap_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mayra Juanita Sarmiento Hernandez COD: 817062

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp

# %% [markdown]
# ## 3.1 Bifurcación de punto de silla
#
# *   Para los siguientes ejercicos, grafique todos los posibles campos vectoriales cualitativamente diferentes cuando r varía.
# *   Demuestre que se produce una bifurcación de punto de silla en un valor crítico de r.
#
# *   Grafique el diagrama de bifurcación de puntos fijos x vs r

# %% [markdown]
# ### 3.1.1
# \begin{equation}
# \dot{x} =1+rx+{x}^{2}
# \end{equation}

# %%
r=[-2, 0, 2]
x=np.linspace(-3,3,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=1+r[i]*Y+Y**2 
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=2
x_dot=1+r*x+x**2
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=1+r*x+x**2
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [-1]

# %%
def fun (t,x,r,b):
  return 1+r*x+x**2

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -10, 10])
plt.grid()

# %% [markdown]
# ### 3.1.2
# \begin{equation}
# \dot{x} =r-cosh(x)
# \end{equation}

# %%
r=[0, 1, 2]
x=np.linspace(-3,3,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]-np.cosh(Y) 
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=1
x_dot=r-np.cosh(x)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r-sp.cosh(x)
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return r-np.cosh(x)

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([0, 5, -2.5, 2.5])
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in cosh

# %% [markdown]
# ### 3.1.3
# \begin{equation}
# \dot{x} =r+x-ln(1+x)
# \end{equation}

# %%
r=[-1, 0, 1]
x=np.linspace(-2,4,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]+Y-np.log(1+Y)
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in log

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r+x-np.log(1+x)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r+x-sp.log(1+x)
roots=np.abs(sp.solve(x_dot1))
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# [0 0]

# %%
def fun (t,x,r,b):
  return r+x-np.log(1+x)

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-1,5,0.2):
  for x0 in np.arange(-1,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-1,5,0.2):
  for x0 in np.arange(-1,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2, 5, -1.2, 2.5])
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/common.py:111: RuntimeWarning: invalid value encountered in multiply
#   y1 = y0 + h0 * direction * f0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in subtract
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %% [markdown]
# ### 3.1.4
# \begin{equation}
# \dot{x} =r+\frac{1}{2}x-\frac{x}{1+x}
# \end{equation}

# %%
r=[-1/2, 0, 1/2]
x=np.linspace(-3,5,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]+(1/2)*Y-(Y)/(1+Y) 
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r+(1/2)*x-(x/(1+x))
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r+(1/2)*x-(x/(1+x))
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0.0, 1.00000000000000]

# %%
def fun (t,x,r,b):
  return r+(1/2)*x-(x/(1+x)) 

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-1,1,0.2):
  for x0 in np.arange(-1,1,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-1,1,0.2):
  for x0 in np.arange(-1,1,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-1, 1, -2.5, 2.5])
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/common.py:111: RuntimeWarning: invalid value encountered in multiply
#   y1 = y0 + h0 * direction * f0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# ### 3.1.5
# (Bifurcaciones inusuales) Al discutir la forma normal de la bifurcación del nodo silla de montar, mencionamos la suposición de que $a = \frac{∂f}{∂r}|_{ (x *, r_c)} = 0$. Para ver qué puede suceder si $a = \frac{∂f}{∂r} = | _ {(x *, r_c)} \neq 0$, dibuje los campos vectoriales para los siguientes ejemplos y luego trace los puntos fijos como una función de r
#
#
# 1.   $\dot{x}=r^2-x^2$
# 2.   $\dot{x}=r^2+x^2$

# %% [markdown]
# ## 3.2 Bifurcación transcritica
#
# *   Para los siguientes ejercicos, grafique todos los posibles campos vectoriales cualitativamente diferentes cuando r varía.
# *   Demuestre que se produce una bifurcación de punto de silla en un valor crítico de r.
#
# *   Grafique el diagrama de bifurcación de puntos fijos x vs r

# %% [markdown]
# ### 3.2.1
# \begin{equation}
# \dot{x} =rx+x^2
# \end{equation}

# %%
r=[-2, 0, 2]
x=np.linspace(-3,3,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]*Y+Y**2 
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r*x+x**2
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r*x+x**2
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return r*x+x**2

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,2.5,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,2.5,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 2.5, -2.5, 2.5])
plt.grid()

# %% [markdown]
# ### 3.2.2
# \begin{equation}
# \dot{x} =rx-ln(1+x)
# \end{equation}

# %%
r=[-2, 0, 2]
x=np.linspace(-1,3,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]*Y-np.log(1+Y)
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r*x-np.log(1+x)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r*x-sp.log(1+x)
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# [0]

# %%
def fun (t,x,r,b):
  return r*x-np.log(1+x) 

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-1,2.5,0.2):
  for x0 in np.arange(-1,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-1,2.5,0.2):
  for x0 in np.arange(-1,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-1, 2.5, -2.5, 2.5])
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/common.py:111: RuntimeWarning: invalid value encountered in multiply
#   y1 = y0 + h0 * direction * f0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in subtract
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %% [markdown]
# ### 3.2.3
# \begin{equation}
# \dot{x} =x-rx(1-x)
# \end{equation}

# %%
r=[-1, 0, 1]
x=np.linspace(-3,3,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=Y-r[i]*Y*(1-Y)
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=x-r*x*(1-x)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=x-r*x*(1-x)
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return x-r*x*(1-x) 

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 3, -2.5, 2.5])
plt.grid()

# %% [markdown]
# ### 3.2.4
# \begin{equation}
# \dot{x} =x(r-{e}^{x})
# \end{equation}

# %%
r=[-1, 0, 1]
x=np.linspace(-1,1,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=Y*(r[i]-np.exp(Y))
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=1
x_dot=x*(r-np.exp(x))
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=x*(r-sp.exp(x))
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return x*(r-np.exp(x))

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 3, -2.5, 2.5])
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %% [markdown]
# ## 3.4 Bifurcación de la horquilla
#
# *   Para los siguientes ejercicos, grafique todos los posibles campos vectoriales cualitativamente diferentes cuando r varía.
# *   Demuestre que se produce una bifurcación de punto de silla en un valor crítico de r.
#
# *   Grafique el diagrama de bifurcación de puntos fijos x vs r

# %% [markdown]
# ### 3.4.1
# \begin{equation}
# \dot{x} =rx+4x^3
# \end{equation}

# %%
r=[-4, 0, 4]
x=np.linspace(-1,1,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]*Y+4*Y**3
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r*x+4*x**3
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r*x+4*x**3
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return r*x+4*x**3

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 3, -2.5, 2.5])
plt.grid()

# %% [markdown]
# ### 3.4.2
# \begin{equation}
# \dot{x} =rx-sinh(x)
# \end{equation}

# %%
r=[-1, 0, 1]
x=np.linspace(-1,1,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]*Y-np.sinh(Y)
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=1
x_dot=x*r-np.sinh(x)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r*x-sp.sinh(x)
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-9-5f8c22903746> in <module>()
#      15 x=sp.symbols('x')
#      16 x_dot1=r*x-sp.sinh(x)
# ---> 17 roots=sp.solve(x_dot1)
#      18 print(roots)
#      19 for j in range(len(roots)):
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1095     ###########################################################################
#    1096     if bare_f:
# -> 1097         solution = _solve(f[0], *symbols, **flags)
#    1098     else:
#    1099         solution = _solve_system(f, symbols, **flags)
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1714
#    1715     if result is False:
# -> 1716         raise NotImplementedError('\n'.join([msg, not_impl_msg % f]))
#    1717
#    1718     if flags.get('simplify', True):
#
# NotImplementedError: multiple generators [x, exp(x)]
# No algorithms are implemented to solve equation x - exp(x)/2 + exp(-x)/2

# %%
def fun (t,x,r,b):
  return r*x-np.sinh(x)

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 3, -2.5, 2.5])
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in sinh
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in subtract

# %% [markdown]
# ### 3.4.3
# \begin{equation}
# \dot{x} =rx-4x^3
# \end{equation}

# %%
r=[-1, 0, 1]
x=np.linspace(-1,1,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]*Y-4*Y**3
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r*x-4*x**3
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r*x-4*x**3
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return r*x-4*x**3

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 3, -2.5, 2.5])
plt.grid()

# %% [markdown]
# ### 3.4.4
# \begin{equation}
# \dot{x} =x+\frac{rx}{1+x^2}
# \end{equation}

# %%
r=[-2, -1, 0]
x=np.linspace(-5,5,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=Y+(r[i]*Y)/(1+x**2)
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-5,5,100)
r=-1
x_dot=x+(r*x/(1+x**2))
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=x+(r*x/(1+x**2))
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return x+(r*x/(1+x**2))

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-3,3,0.2):
  for x0 in np.arange(-3,3,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-3,3,0.2):
  for x0 in np.arange(-3,3,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-3, 3, -3, 3])
plt.grid()

# %% [markdown]
# En los siguientes ejercicios
# *   Encuentre los valores de r en los que se encuentran las bifurcaciones y clasifiquelos
# *   Grafique el diagrama de bifurcación

# %% [markdown]
# ### 3.4.5
# \begin{equation}
# \dot{x} =r-3x^3
# \end{equation}

# %% [markdown]
# (NO HAY BIFURCACIONES)

# %%
def fun (t,x,r,b):
  return r-3*x**3

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-10,10,0.2):
  for x0 in np.arange(-10,10,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-10,10,0.2):
  for x0 in np.arange(-10,10,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-10, 10, -10, 10])
plt.grid()

# %% [markdown]
# ### 3.4.6
# \begin{equation}
# \dot{x} =rx-\frac{x}{1+x}
# \end{equation}

# %% [markdown]
# bifurcación transcritica

# %%
def fun (t,x,r,b):
  return r*x-(x/(1+x))

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2,2,0.2):
  for x0 in np.arange(-2,2,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2,2,0.2):
  for x0 in np.arange(-2,2,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2, 2, -2, 2])
plt.grid()

# %% [markdown]
# ### 3.4.7
# \begin{equation}
# \dot{x} =5-r{e}^{{-x}^{2}}
# \end{equation}

# %% [markdown]
# bifurcación de punto de silla

# %%
def fun (t,x,r,b):
  return 5-r*np.exp(-x**2)

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(2,10,0.2):
  for x0 in np.arange(-6,6,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(2,10,0.2):
  for x0 in np.arange(-6,6,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([2, 10, -6, 6])
plt.grid()

# %% [markdown]
# ### 3.4.8
# \begin{equation}
# \dot{x} =rx-\frac{x}{1+x^2}
# \end{equation}

# %% [markdown]
# parece bifurcación de horquilla

# %%
def fun (t,x,r,b):
  return r*x-(x/(1+x**2))

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,2.5,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,2.5,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 2.5, -2.5, 2.5])
plt.grid()

# %% [markdown]
# ### 3.4.9
# \begin{equation}
# \dot{x} =x+tanh(rx)
# \end{equation}

# %% [markdown]
# bifurcación de horquilla

# %%
def fun (t,x,r,b):
  return x+np.tanh(r*x)

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,2.5,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,2.5,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 2.5, -2.5, 2.5])
plt.grid()

# %% [markdown]
# ### 3.4.10
# \begin{equation}
# \dot{x} =rx+\frac{x^3}{1+x^2}
# \end{equation}

# %% [markdown]
# no se

# %%
def fun (t,x,r,b):
  return r*x+(x**3/(1+x**2))

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 3, -2.5, 2.5])
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# ### 3.4.11
